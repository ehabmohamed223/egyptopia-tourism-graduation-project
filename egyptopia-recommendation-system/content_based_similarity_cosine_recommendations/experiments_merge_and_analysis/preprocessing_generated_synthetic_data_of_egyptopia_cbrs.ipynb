# %%
import pandas as pd
import glob

# %% [markdown]
# ## Uploading Generated Syntatic Data

# %%
## Multiple User Preferences
csv_files = glob.glob(r"../synthetic_data_experiments/experiment_*.csv")

# %%
single_inputs = pd.read_csv(r"../synthetic_data_experiments/single_preferences_results.csv")

# %%
print(csv_files)
# Out:
# ['../synthetic_data_experiments\\experiment_1.csv', '../synthetic_data_experiments\\experiment_2.csv', '../synthetic_data_experiments\\experiment_3.csv', '../synthetic_data_experiments\\experiment_4.csv', '../synthetic_data_experiments\\experiment_5.csv', '../synthetic_data_experiments\\experiment_6.csv', '../synthetic_data_experiments\\experiment_7.csv', '../synthetic_data_experiments\\experiment_8.csv', '../synthetic_data_experiments\\experiment_9.csv']

# %% [markdown]
# ## Merging Multiple User Preference Datasets

# %%
dataframes = []
for file in csv_files:
    df = pd.read_csv(file)
    dataframes.append(df)
final_df = pd.concat(dataframes, ignore_index=True)

# %% [markdown]
# ## EDA

# %%
final_df.head()
# Out:
#    Scenario        Categories                              Cities  \
# 0         1          Mountain           Beni Suef, Hurghada, Qena
# 1         2        Water Park     Red Sea, Cairo, Sharm El Sheikh
# 2         3  Fortress, Mosque  Qena, Sharqia, Beheira, Alexandria
# 3         4        Theme Park               Fayoum, Assiut, Aswan
# 4         5             Beach       Sohag, Sharm El Sheikh, Cairo
#
#                                        Tourism_Types  Precision@k  \
# 0  Religious and Spiritual Attractions, Medical A...     0.714286
# 1           Medical Attractions, Natural Attractions     1.000000
# 2  Religious and Spiritual Attractions, Entertain...     1.000000
# 3  Religious and Spiritual Attractions, Entertain...     1.000000
# 4  Entertainment and Modern Attractions, Cultural...     1.000000
#
#    Preference_Coverage@k  Category_Diversity  Tourism_Type_Diversity
# 0               0.666667            0.607143                0.607143
# 1               1.000000            0.714286                0.607143
# 2               0.777778            0.857143                0.619048
# 3               0.285714            0.750000                0.333333
# 4               0.833333            0.750000                0.750000

# %% [markdown]
# ## Identifying Duplicate Scenarios

# %%
final_df.duplicated().sum()
# Out:
# 1

# %%
final_df = final_df.drop_duplicates()

# %%
single_inputs.head()
# Out:
#      Category City Tourism Type  Precision@k  Preference_Coverage@k  \
# 0  Theme Park  NaN          NaN     0.500000                    1.0
# 1  Water Park  NaN          NaN     0.428571                    1.0
# 2         Zoo  NaN          NaN     0.285714                    1.0
# 3       Tower  NaN          NaN     0.428571                    1.0
# 4    Shopping  NaN          NaN     0.500000                    1.0
#
#    Category_Diversity  Tourism_Type_Diversity
# 0            0.750000                     0.0
# 1            0.714286                     0.0
# 2            0.642857                     0.0
# 3            0.714286                     0.0
# 4            0.750000                     0.0

# %% [markdown]
# ## Integrating Data from Multiple and Single Scenario Datasets

# %%
multiple_inputs = final_df.iloc[:,1:]

# %%
single_inputs = single_inputs.rename(columns={
    'Category': 'Categories',
    'City': 'Cities',
    'Tourism Type': 'Tourism_Types'
})

single_inputs.columns == multiple_inputs.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True])

# %%
final_simulation =  pd.concat([multiple_inputs, single_inputs], ignore_index=True)

# %%
final_simulation
# Out:
#            Categories                              Cities  \
# 0            Mountain           Beni Suef, Hurghada, Qena
# 1          Water Park     Red Sea, Cairo, Sharm El Sheikh
# 2    Fortress, Mosque  Qena, Sharqia, Beheira, Alexandria
# 3          Theme Park               Fayoum, Assiut, Aswan
# 4               Beach       Sohag, Sharm El Sheikh, Cairo
# ..                ...                                 ...
# 500               NaN                                 NaN
# 501               NaN                                 NaN
# 502               NaN                                 NaN
# 503               NaN                                 NaN
# 504               NaN                                 NaN
#
#                                          Tourism_Types  Precision@k  \
# 0    Religious and Spiritual Attractions, Medical A...     0.714286
# 1             Medical Attractions, Natural Attractions     1.000000
# 2    Religious and Spiritual Attractions, Entertain...     1.000000
# 3    Religious and Spiritual Attractions, Entertain...     1.000000
# 4    Entertainment and Modern Attractions, Cultural...     1.000000
# ..                                                 ...          ...
# 500               Entertainment and Modern Attractions     0.857143
# 501                                Natural Attractions     0.785714
# 502                Religious and Spiritual Attractions     0.642857
# 503                                Medical Attractions     0.642857
# 504                Cultural and Historical Attractions     0.857143
#
#      Preference_Coverage@k  Category_Diversity  Tourism_Type_Diversity
# 0                 0.666667            0.607143                0.607143
# 1                 1.000000            0.714286                0.607143
# 2                 0.777778            0.857143                0.619048
# 3                 0.285714            0.750000                0.333333
# 4                 0.833333            0.750000                0.750000
# ..                     ...                 ...                     ...
# 500               1.000000            0.000000                0.928571
# 501               1.000000            0.000000                0.892857
# 502               1.000000            0.000000                0.821429
# 503               1.000000            0.000000                0.821429
# 504               1.000000            0.000000                0.928571
#
# [505 rows x 7 columns]

# %% [markdown]
# ## Null Value Handling in Multiple and Single Scenario Datasets

# %%
columns_to_fill = ['Cities', 'Categories', 'Tourism_Types']
final_simulation[columns_to_fill] = final_simulation[columns_to_fill].fillna("No Input")

# %%
final_simulation
# Out:
#            Categories                              Cities  \
# 0            Mountain           Beni Suef, Hurghada, Qena
# 1          Water Park     Red Sea, Cairo, Sharm El Sheikh
# 2    Fortress, Mosque  Qena, Sharqia, Beheira, Alexandria
# 3          Theme Park               Fayoum, Assiut, Aswan
# 4               Beach       Sohag, Sharm El Sheikh, Cairo
# ..                ...                                 ...
# 500          No Input                            No Input
# 501          No Input                            No Input
# 502          No Input                            No Input
# 503          No Input                            No Input
# 504          No Input                            No Input
#
#                                          Tourism_Types  Precision@k  \
# 0    Religious and Spiritual Attractions, Medical A...     0.714286
# 1             Medical Attractions, Natural Attractions     1.000000
# 2    Religious and Spiritual Attractions, Entertain...     1.000000
# 3    Religious and Spiritual Attractions, Entertain...     1.000000
# 4    Entertainment and Modern Attractions, Cultural...     1.000000
# ..                                                 ...          ...
# 500               Entertainment and Modern Attractions     0.857143
# 501                                Natural Attractions     0.785714
# 502                Religious and Spiritual Attractions     0.642857
# 503                                Medical Attractions     0.642857
# 504                Cultural and Historical Attractions     0.857143
#
#      Preference_Coverage@k  Category_Diversity  Tourism_Type_Diversity
# 0                 0.666667            0.607143                0.607143
# 1                 1.000000            0.714286                0.607143
# 2                 0.777778            0.857143                0.619048
# 3                 0.285714            0.750000                0.333333
# 4                 0.833333            0.750000                0.750000
# ..                     ...                 ...                     ...
# 500               1.000000            0.000000                0.928571
# 501               1.000000            0.000000                0.892857
# 502               1.000000            0.000000                0.821429
# 503               1.000000            0.000000                0.821429
# 504               1.000000            0.000000                0.928571
#
# [505 rows x 7 columns]

# %% [markdown]
# ## Extracting the Number of User Inputs for Each Preference Type For Analysing The CBRS Perfromance

# %%
final_simulation['Number_of_Categories'] = final_simulation['Categories'].apply(
    lambda x: 0 if pd.isna(x) else x.count(',') + 1
)

final_simulation['Number_of_Cities'] = final_simulation['Cities'].apply(
    lambda x: 0 if pd.isna(x) else x.count(',') + 1
)

final_simulation['Number_of_Tourism_Types'] = final_simulation['Tourism_Types'].apply(
    lambda x: 0 if pd.isna(x) else x.count(',') + 1
)

# %%
final_simulation
# Out:
#            Categories                              Cities  \
# 0            Mountain           Beni Suef, Hurghada, Qena
# 1          Water Park     Red Sea, Cairo, Sharm El Sheikh
# 2    Fortress, Mosque  Qena, Sharqia, Beheira, Alexandria
# 3          Theme Park               Fayoum, Assiut, Aswan
# 4               Beach       Sohag, Sharm El Sheikh, Cairo
# ..                ...                                 ...
# 500          No Input                            No Input
# 501          No Input                            No Input
# 502          No Input                            No Input
# 503          No Input                            No Input
# 504          No Input                            No Input
#
#                                          Tourism_Types  Precision@k  \
# 0    Religious and Spiritual Attractions, Medical A...     0.714286
# 1             Medical Attractions, Natural Attractions     1.000000
# 2    Religious and Spiritual Attractions, Entertain...     1.000000
# 3    Religious and Spiritual Attractions, Entertain...     1.000000
# 4    Entertainment and Modern Attractions, Cultural...     1.000000
# ..                                                 ...          ...
# 500               Entertainment and Modern Attractions     0.857143
# 501                                Natural Attractions     0.785714
# 502                Religious and Spiritual Attractions     0.642857
# 503                                Medical Attractions     0.642857
# 504                Cultural and Historical Attractions     0.857143
#
#      Preference_Coverage@k  Category_Diversity  Tourism_Type_Diversity  \
# 0                 0.666667            0.607143                0.607143
# 1                 1.000000            0.714286                0.607143
# 2                 0.777778            0.857143                0.619048
# 3                 0.285714            0.750000                0.333333
# 4                 0.833333            0.750000                0.750000
# ..                     ...                 ...                     ...
# 500               1.000000            0.000000                0.928571
# 501               1.000000            0.000000                0.892857
# 502               1.000000            0.000000                0.821429
# 503               1.000000            0.000000                0.821429
# 504               1.000000            0.000000                0.928571
#
#      Number_of_Categories  Number_of_Cities  Number_of_Tourism_Types
# 0                       1                 3                        2
# 1                       1                 3                        2
# 2                       2                 4                        3
# 3                       1                 3                        3
# 4                       1                 3                        2
# ..                    ...               ...                      ...
# 500                     1                 1                        1
# 501                     1                 1                        1
# 502                     1                 1                        1
# 503                     1                 1                        1
# 504                     1                 1                        1
#
# [505 rows x 10 columns]

# %%
final_simulation.to_excel('final_simulation_results_of_egyptopia_cbrs.xlsx', index=False)

# %% [markdown]
# ## Applying Descriptive Analysis

# %%
final_simulation.columns = [col.replace('@k', '') for col in final_simulation.columns]

# %%
final_simulation.describe()
# Out:
#         Precision  Preference_Coverage  Category_Diversity  \
# count  505.000000           505.000000          505.000000
# mean     0.926025             0.852647            0.766150
# std      0.192416             0.135780            0.205521
# min      0.214286             0.250000            0.000000
# 25%      1.000000             0.777778            0.750000
# 50%      1.000000             0.875000            0.807143
# 75%      1.000000             0.937500            0.880952
# max      1.000000             1.000000            0.928571
#
#        Tourism_Type_Diversity  Number_of_Categories  Number_of_Cities  \
# count              505.000000            505.000000        505.000000
# mean                 0.621311              4.742574          3.061386
# std                  0.231746              2.376528          1.460524
# min                  0.000000              1.000000          1.000000
# 25%                  0.607143              3.000000          2.000000
# 50%                  0.678571              5.000000          3.000000
# 75%                  0.750000              7.000000          4.000000
# max                  1.000000              9.000000          7.000000
#
#        Number_of_Tourism_Types
# count               505.000000
# mean                  1.998020
# std                   0.793073
# min                   1.000000
# 25%                   1.000000
# 50%                   2.000000
# 75%                   3.000000
# max                   3.000000
