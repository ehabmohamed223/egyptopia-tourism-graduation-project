# %%
import pandas as pd 
import numpy as np 
import re
from fuzzywuzzy import process, fuzz
import os
import shutil
import glob
from difflib import SequenceMatcher

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# ## For Data Processing

# %%
city_names = [
    'Giza', 'Cairo', 'Sharm El Sheikh', 'Hurghada', 'North Coast', 'Alexandria',
    'Fayoum', 'Beni Suef', 'Marsa Matrouh', 'Marsa Alam', 'El Gouna', 'Dahab',
    'Sinai', 'Red Sea', 'Suez', 'Assiut', 'New Valley', 'Aswan', 'Luxor',
    'Beheira', 'Sohag', 'Minya', 'Ismailia', 'Port Said', 'Qena', 'Qalyubia', 'Sharqia'
]

# %%
def add_sequential_id(df, start_range):    
    df = df.copy()  
    id_list = list(range(start_range, start_range + df.shape[0]))  
    
    df.insert(0, 'id', id_list) 
    
    return df

# %% [markdown]
# ### Activities IDs Ranges

# %%
# safari_data             Range ---> 7000
# ballon_tours_data       Range ---> 8000
# camel_tour              Range ---> 9000
# diving_data             Range ---> 10000
# submarine_tour          Range ---> 11000
# swimming_and_dolphins   Range ---> 12000

# %%
def insert_tourism_type(df, tourism_type):
    df = df.copy()  
    df['Activity Type'] = tourism_type 
    return df

# %%
def extract_city_name(title, cities):
    
    for city in cities:
        if re.search(rf"\b{re.escape(city)}\b", title, re.IGNORECASE):
            return city  
    
    best_match = process.extractOne(title, cities, scorer=fuzz.partial_ratio)
    if best_match and best_match[1] >= 75:
        return best_match[0]
    
    return None

# %%
def get_best_match(title, files, threshold=0.68):
    best_match = None
    best_ratio = 0

    for file in files:
        filename = os.path.splitext(os.path.basename(file))[0]  
        ratio = SequenceMatcher(None, title.lower(), filename.lower()).ratio()

        if ratio > best_ratio and ratio >= threshold:
            best_match = file
            best_ratio = ratio

    return best_match

def move_image_to_id_file(df, old_folder_path, new_folder_path):
    all_images = glob.glob(os.path.join(old_folder_path, "*.*")) 
    missing_ids = []  

    for _, row in df.iterrows():
        title_clean = str(row['Title']).strip()
        best_match = get_best_match(title_clean, all_images, threshold=0.75)

        if best_match:
            old_image_path = best_match
            file_extension = os.path.splitext(old_image_path)[1]
            webp_image_path = os.path.splitext(old_image_path)[0] + ".webp"

            if file_extension.lower() != ".webp":
                with Image.open(old_image_path) as img:
                    img.save(webp_image_path, "WEBP")
                os.remove(old_image_path)
                print(f" Converted: {old_image_path} → {webp_image_path}")
            else:
                webp_image_path = old_image_path  

            id_folder = os.path.join(new_folder_path, str(row['id']))
            os.makedirs(id_folder, exist_ok=True)
            new_image_path = os.path.join(id_folder, os.path.basename(webp_image_path))

            shutil.move(webp_image_path, new_image_path)
            print(f"📂 Moved: {webp_image_path} → {new_image_path}")
        else:
            missing_ids.append(row['id'])  

    return missing_ids

# %% [markdown]
# ## Data Uploading

# %%
safari_data = pd.read_csv("safari_data.csv")
ballon_tours_data = pd.read_csv("ballon_tours_data.csv")
camel_tour = pd.read_csv("camel_tour.csv")
diving_data = pd.read_csv("diving_data.csv")
submarine_tour = pd.read_csv("submarine_tour.csv")
swimming_and_dolphins = pd.read_csv("swimming_and_dolphins.csv")

# %% [markdown]
# ## Safari Data Processing

# %%
safari_data.head()
# Out:
#                                                Title  Rating  \
# 0  Sharm El-Sheikh: Ultimate ATV Quad, Stargazing...     4.8
# 1  Hurghada: Desert Quad Bike Camel Ride with Opt...     4.5
# 2  Giza Sunrise Pyramid Guided Tour With Camel Ri...     4.8
# 3  Hurghada: VIP Quad, Sea, Camel, Safari, Starga...     4.3
# 4  Hurghada: Sunset Quad Bike, Camel w/ Opt Starg...     4.4
#
#                                       Price  \
# 0  From\nE£2,001\nFrom\nE£1,000\nper person
# 1      From\nE£886\nFrom\nE£443\nper person
# 2  From\nE£2,046\nFrom\nE£1,023\nper person
# 3      From\nE£545\nFrom\nE£327\nper person
# 4      From\nE£852\nFrom\nE£511\nper person
#
#                                                 Link
# 0  https://www.getyourguide.com/sharm-el-sheikh-l...
# 1  https://www.getyourguide.com/hurghada-l403/hur...
# 2  https://www.getyourguide.com/cairo-l92/giza-su...
# 3  https://www.getyourguide.com/hurghada-l403/hur...
# 4  https://www.getyourguide.com/hurghada-l403/sun...

# %%
safari_data['City'] = safari_data['Title'].apply(lambda x: extract_city_name(x, city_names))

# %%
for i in safari_data[safari_data['City'].isna()]['Title'] : 
    print(i)
# Out:
# Makadi Bay: Sunset Quad & ATV Adventure & Seaview
# camel ride with sunset and star watching
# Desert Sunset Quad Biking Safari, Dinner, Camel Ride
# Discover Wadi Hitan, Egypts Prehistoric Wonder!
# All-inclusive private Trip Pyramids Sphinx, Camel, VIP Lunch
# Morning Trip: Desert Safari Riding a Speed Quad Bike, Pickup
# Makadi Bay: Mega Tour Jeep, ATV, Buggy, Camel, Dinner & Show
# Desert Safari by Quad Bike Around Pyramids
# 2-Day Black & White Deserts Tour and Activities
# Makadi Bay: 2H Quad Bike, Camel, Stargazing, Dinner & Show

# %%
safari_data = safari_data.dropna(subset=['City'])

# %%
safari_data.head()
# Out:
#                                                Title  Rating  \
# 0  Sharm El-Sheikh: Ultimate ATV Quad, Stargazing...     4.8
# 1  Hurghada: Desert Quad Bike Camel Ride with Opt...     4.5
# 2  Giza Sunrise Pyramid Guided Tour With Camel Ri...     4.8
# 3  Hurghada: VIP Quad, Sea, Camel, Safari, Starga...     4.3
# 4  Hurghada: Sunset Quad Bike, Camel w/ Opt Starg...     4.4
#
#                                       Price  \
# 0  From\nE£2,001\nFrom\nE£1,000\nper person
# 1      From\nE£886\nFrom\nE£443\nper person
# 2  From\nE£2,046\nFrom\nE£1,023\nper person
# 3      From\nE£545\nFrom\nE£327\nper person
# 4      From\nE£852\nFrom\nE£511\nper person
#
#                                                 Link             City
# 0  https://www.getyourguide.com/sharm-el-sheikh-l...  Sharm El Sheikh
# 1  https://www.getyourguide.com/hurghada-l403/hur...         Hurghada
# 2  https://www.getyourguide.com/cairo-l92/giza-su...             Giza
# 3  https://www.getyourguide.com/hurghada-l403/hur...         Hurghada
# 4  https://www.getyourguide.com/hurghada-l403/sun...         Hurghada

# %%
safari_data = add_sequential_id (safari_data, 7000)

# %%
safari_data.head()
# Out:
#      id                                              Title  Rating  \
# 0  7000  Sharm El-Sheikh: Ultimate ATV Quad, Stargazing...     4.8
# 1  7001  Hurghada: Desert Quad Bike Camel Ride with Opt...     4.5
# 2  7002  Giza Sunrise Pyramid Guided Tour With Camel Ri...     4.8
# 3  7003  Hurghada: VIP Quad, Sea, Camel, Safari, Starga...     4.3
# 4  7004  Hurghada: Sunset Quad Bike, Camel w/ Opt Starg...     4.4
#
#                                       Price  \
# 0  From\nE£2,001\nFrom\nE£1,000\nper person
# 1      From\nE£886\nFrom\nE£443\nper person
# 2  From\nE£2,046\nFrom\nE£1,023\nper person
# 3      From\nE£545\nFrom\nE£327\nper person
# 4      From\nE£852\nFrom\nE£511\nper person
#
#                                                 Link             City
# 0  https://www.getyourguide.com/sharm-el-sheikh-l...  Sharm El Sheikh
# 1  https://www.getyourguide.com/hurghada-l403/hur...         Hurghada
# 2  https://www.getyourguide.com/cairo-l92/giza-su...             Giza
# 3  https://www.getyourguide.com/hurghada-l403/hur...         Hurghada
# 4  https://www.getyourguide.com/hurghada-l403/sun...         Hurghada

# %% [markdown]
# ## Ballon Tours Dataset Handling

# %%
ballon_tours_data.head()
# Out:
#                                                Title  Rating  \
# 0      Luxor: Hot Air Balloon Ride over Luxor Relics     4.9
# 1  Hurghada: Luxor Hot Air Balloon Ride and Day T...     4.4
# 2                Luxor: Morning Hot Air Balloon Ride     4.4
# 3  Luxor: Hot Air Balloon Ride with Full-Day Sigh...     5.0
# 4  Hurghada: 2-Day Luxor Tour with Hotel, Balloon...     4.5
#
#                                       Price  \
# 0  From\nE£4,681\nFrom\nE£3,277\nper person
# 1                 From\nE£7,900\nper person
# 2                 From\nE£2,896\nper person
# 3  From\nE£8,427\nFrom\nE£4,634\nper person
# 4                From\nE£13,167\nper person
#
#                                                 Link
# 0  https://www.getyourguide.com/luxor-l109/luxor-...
# 1  https://www.getyourguide.com/hurghada-l403/fro...
# 2  https://www.getyourguide.com/luxor-l109/luxor-...
# 3  https://www.getyourguide.com/luxor-l109/luxor-...
# 4  https://www.getyourguide.com/luxor-l109/hurgha...

# %%
ballon_tours_data['City'] = ballon_tours_data['Title'].apply(lambda x: extract_city_name(x, city_names))

# %%
for i in ballon_tours_data[ballon_tours_data['City'].isna()]['Title'] : 
    print(i)
# Out:
# Egypt: Private 5-Day Tour, Nile Cruise, Flights, Balloon
# East and west banks private day tour included Balloon Ride

# %%
ballon_tours_data = ballon_tours_data.dropna(subset=['City'])

# %%
ballon_tours_data = add_sequential_id (ballon_tours_data, 8000)

# %%
ballon_tours_data
# Out:
#       id                                              Title  Rating  \
# 0   8000      Luxor: Hot Air Balloon Ride over Luxor Relics     4.9
# 1   8001  Hurghada: Luxor Hot Air Balloon Ride and Day T...     4.4
# 2   8002                Luxor: Morning Hot Air Balloon Ride     4.4
# 3   8003  Luxor: Hot Air Balloon Ride with Full-Day Sigh...     5.0
# 4   8004  Hurghada: 2-Day Luxor Tour with Hotel, Balloon...     4.5
# ..   ...                                                ...     ...
# 63  8061  From Marsa Alam: 5-Day Egypt Tour with Nile Cr...     4.4
# 64  8062  From Marsa Alam: 3 night Nile Cruise with Hot ...     4.4
# 65  8063  Hurghada:10-Day Egypt Tour, Nile Cruise, Ballo...     5.0
# 66  8064  Marsa Alam: 4 Days Nile cruise to Aswan with h...     4.4
# 67  8065  From Hurghada: 6-Day cruise to Aswan with Hot ...     5.0
#
#                                        Price  \
# 0   From\nE£4,681\nFrom\nE£3,277\nper person
# 1                  From\nE£7,900\nper person
# 2                  From\nE£2,896\nper person
# 3   From\nE£8,427\nFrom\nE£4,634\nper person
# 4                 From\nE£13,167\nper person
# ..                                       ...
# 63                From\nE£63,954\nper person
# 64                From\nE£56,430\nper person
# 65                From\nE£56,355\nper person
# 66                From\nE£56,430\nper person
# 67                From\nE£67,716\nper person
#
#                                                  Link        City
# 0   https://www.getyourguide.com/luxor-l109/luxor-...       Luxor
# 1   https://www.getyourguide.com/hurghada-l403/fro...    Hurghada
# 2   https://www.getyourguide.com/luxor-l109/luxor-...       Luxor
# 3   https://www.getyourguide.com/luxor-l109/luxor-...       Luxor
# 4   https://www.getyourguide.com/luxor-l109/hurgha...    Hurghada
# ..                                                ...         ...
# 63  https://www.getyourguide.com/luxor-l109/from-m...  Marsa Alam
# 64  https://www.getyourguide.com/luxor-l109/from-m...  Marsa Alam
# 65  https://www.getyourguide.com/hurghada-l403/hur...    Hurghada
# 66  https://www.getyourguide.com/marsa-alam-l422/m...  Marsa Alam
# 67  https://www.getyourguide.com/hurghada-l403/fro...    Hurghada
#
# [66 rows x 6 columns]

# %% [markdown]
# ## Camel Tour Dataset Handling

# %%
camel_tour.head()
# Out:
#                                                Title  Rating  \
# 0  Sharm El-Sheikh: Ultimate ATV Quad, Stargazing...     4.8
# 1  Cairo: Pyramids & Great Sphinx Private Tour wi...     4.9
# 2  Hurghada: Desert Quad Bike Camel Ride with Opt...     4.5
# 3  Hurghada: VIP Quad, Sea, Camel, Safari, Starga...     4.3
# 4  Giza Sunrise Pyramid Guided Tour With Camel Ri...     4.8
#
#                                       Price  \
# 0  From\nE£2,001\nFrom\nE£1,000\nper person
# 1  From\nE£1,158\nFrom\nE£1,042\nper person
# 2      From\nE£886\nFrom\nE£443\nper person
# 3      From\nE£545\nFrom\nE£327\nper person
# 4  From\nE£2,046\nFrom\nE£1,023\nper person
#
#                                                 Link
# 0  https://www.getyourguide.com/sharm-el-sheikh-l...
# 1  https://www.getyourguide.com/cairo-l92/private...
# 2  https://www.getyourguide.com/hurghada-l403/hur...
# 3  https://www.getyourguide.com/hurghada-l403/hur...
# 4  https://www.getyourguide.com/cairo-l92/giza-su...

# %%
camel_tour['City'] = camel_tour['Title'].apply(lambda x: extract_city_name(x, city_names))

# %%
camel_tour = camel_tour.dropna(subset=['City'])

# %%
camel_tour = add_sequential_id (camel_tour, 9000)

# %%
camel_tour
# Out:
#       id                                              Title  Rating  \
# 0   9000  Sharm El-Sheikh: Ultimate ATV Quad, Stargazing...     4.8
# 1   9001  Cairo: Pyramids & Great Sphinx Private Tour wi...     4.9
# 2   9002  Hurghada: Desert Quad Bike Camel Ride with Opt...     4.5
# 3   9003  Hurghada: VIP Quad, Sea, Camel, Safari, Starga...     4.3
# 4   9004  Giza Sunrise Pyramid Guided Tour With Camel Ri...     4.8
# ..   ...                                                ...     ...
# 85  9079  Sharm El Sheikh: Quad Biking, Camel Ride & Bed...     4.6
# 86  9080  VIP Cairo Experience: Pyramids, ATV Adventure ...     4.3
# 87  9081  Hurghada: 4 Days Tour Horse, Camel, Spa, ATV, ...     4.3
# 88  9082  Desert Safari Around The Pyramids of Giza With...     4.0
# 90  9083  Hurghada: Quad Bike Safari, Camel Horse Ride, ...     5.0
#
#                                         Price  \
# 0    From\nE£2,001\nFrom\nE£1,000\nper person
# 1    From\nE£1,158\nFrom\nE£1,042\nper person
# 2        From\nE£886\nFrom\nE£443\nper person
# 3        From\nE£545\nFrom\nE£327\nper person
# 4    From\nE£2,046\nFrom\nE£1,023\nper person
# ..                                        ...
# 85     From\nE£1,715\nFrom\nE£909\nper person
# 86  From\nE£12,278\nFrom\nE£9,208\nper person
# 87                  From\nE£1,580\nper person
# 88   From\nE£2,182\nFrom\nE£1,309\nper person
# 90                  From\nE£7,373\nper person
#
#                                                  Link             City
# 0   https://www.getyourguide.com/sharm-el-sheikh-l...  Sharm El Sheikh
# 1   https://www.getyourguide.com/cairo-l92/private...            Cairo
# 2   https://www.getyourguide.com/hurghada-l403/hur...         Hurghada
# 3   https://www.getyourguide.com/hurghada-l403/hur...         Hurghada
# 4   https://www.getyourguide.com/cairo-l92/giza-su...             Giza
# ..                                                ...              ...
# 85  https://www.getyourguide.com/sharm-el-sheikh-l...  Sharm El Sheikh
# 86  https://www.getyourguide.com/cairo-l92/vip-cai...            Cairo
# 87  https://www.getyourguide.com/makadi-bay-l4675/...         Hurghada
# 88  https://www.getyourguide.com/giza-governorate-...             Giza
# 90  https://www.getyourguide.com/hurghada-l403/hur...         Hurghada
#
# [84 rows x 6 columns]

# %% [markdown]
# ## Diving Dataset Handling

# %%
diving_data.head()
# Out:
#                                                Title  Rating  \
# 0  Hurghada or Makadi: Discover the Magic of Dolp...     4.9
# 1  Hurghada: Luxury Cruise Trip to Orange Bay wit...     4.9
# 2  Hurghada: Royal Seascope Submarine Cruise with...     4.5
# 3  Hurghada: 6 Islands Tour with Dolphin Watching...     4.7
# 4  Giza: Sakkara, Memphis & Dahshur (Pyramid & Fe...     4.8
#
#                                       Price  \
# 0  From\nE£1,715\nFrom\nE£1,320\nper person
# 1  From\nE£2,949\nFrom\nE£2,802\nper person
# 2    From\nE£1,264\nFrom\nE£884\nper person
# 3  From\nE£2,972\nFrom\nE£2,675\nper person
# 4    From\nE£1,364\nFrom\nE£682\nper person
#
#                                                 Link
# 0  https://www.getyourguide.com/hurghada-l403/hur...
# 1  https://www.getyourguide.com/hurghada-l403/hur...
# 2  https://www.getyourguide.com/hurghada-l403/hur...
# 3  https://www.getyourguide.com/hurghada-l403/hur...
# 4  https://www.getyourguide.com/cairo-l92/giza-sa...

# %%
diving_data['City'] = diving_data['Title'].apply(lambda x: extract_city_name(x, city_names))

# %%
diving_data = diving_data.dropna(subset=['City'])

# %%
diving_data = add_sequential_id (diving_data, 10000)

# %%
diving_data
# Out:
#        id                                              Title  Rating  \
# 0   10000  Hurghada or Makadi: Discover the Magic of Dolp...     4.9
# 1   10001  Hurghada: Luxury Cruise Trip to Orange Bay wit...     4.9
# 2   10002  Hurghada: Royal Seascope Submarine Cruise with...     4.5
# 3   10003  Hurghada: 6 Islands Tour with Dolphin Watching...     4.7
# 4   10004  Giza: Sakkara, Memphis & Dahshur (Pyramid & Fe...     4.8
# ..    ...                                                ...     ...
# 65  10056  Sharm el Sheikh Port : Ras Mohammed Dive Trip ...     5.0
# 66  10057  Hurghada: 1 day DIVING Refrechment, 1 Check & ...     5.0
# 68  10058  From Alexandria Port: City Tour with Citadel a...     4.5
# 69  10059  Hurghada: Private Speedboat To Bayoud Islands ...     3.7
# 70  10060  Hurghada: El Gouna Lagoon Cruise By Speedboat ...     4.6
#
#                                        Price  \
# 0   From\nE£1,715\nFrom\nE£1,320\nper person
# 1   From\nE£2,949\nFrom\nE£2,802\nper person
# 2     From\nE£1,264\nFrom\nE£884\nper person
# 3   From\nE£2,972\nFrom\nE£2,675\nper person
# 4     From\nE£1,364\nFrom\nE£682\nper person
# ..                                       ...
# 65                From\nE£10,902\nper person
# 66                 From\nE£7,432\nper person
# 68                From\nE£13,272\nper person
# 69         From\nE£25,726\nper group up to 2
# 70         From\nE£20,009\nper group up to 2
#
#                                                  Link             City
# 0   https://www.getyourguide.com/hurghada-l403/hur...         Hurghada
# 1   https://www.getyourguide.com/hurghada-l403/hur...         Hurghada
# 2   https://www.getyourguide.com/hurghada-l403/hur...         Hurghada
# 3   https://www.getyourguide.com/hurghada-l403/hur...         Hurghada
# 4   https://www.getyourguide.com/cairo-l92/giza-sa...             Giza
# ..                                                ...              ...
# 65  https://www.getyourguide.com/sharm-el-sheikh-l...  Sharm El Sheikh
# 66  https://www.getyourguide.com/hurghada-l403/hur...         Hurghada
# 68  https://www.getyourguide.com/alexandria-l490/f...       Alexandria
# 69  https://www.getyourguide.com/hurghada-l403/hur...         Hurghada
# 70  https://www.getyourguide.com/hurghada-l403/hur...         Hurghada
#
# [61 rows x 6 columns]

# %% [markdown]
# ## Submarine Tours Dataset Handling

# %%
submarine_tour.head()
# Out:
#                                                Title  Rating  \
# 0  Hurghada: Royal Seascope Submarine Cruise with...     4.5
# 1  Sharm El-Sheikh: Seascope Submarine boat cruis...     4.5
# 2  Hurghada: Semi-Submarine Boat Tour w/ Snorkeli...     4.2
# 3  Hurghada: Sindbad Submarines Red Sea Underwate...     5.0
# 4  Hurghada: Panoramic Semi-Submarine Cruise with...     4.5
#
#                                       Price  \
# 0    From\nE£1,264\nFrom\nE£884\nper person
# 1  From\nE£2,370\nFrom\nE£1,919\nper person
# 2      From\nE£421\nFrom\nE£316\nper person
# 3  From\nE£3,944\nFrom\nE£3,550\nper person
# 4    From\nE£1,843\nFrom\nE£921\nper person
#
#                                                 Link
# 0  https://www.getyourguide.com/hurghada-l403/hur...
# 1  https://www.getyourguide.com/sharm-el-sheikh-l...
# 2  https://www.getyourguide.com/hurghada-l403/hur...
# 3  https://www.getyourguide.com/hurghada-l403/hur...
# 4  https://www.getyourguide.com/hurghada-l403/pan...

# %%
submarine_tour['City'] = submarine_tour['Title'].apply(lambda x: extract_city_name(x, city_names))

# %%
submarine_tour = submarine_tour.dropna(subset=['City'])

# %%
submarine_tour = add_sequential_id (submarine_tour, 110000)

# %%
submarine_tour
# Out:
#         id                                              Title  Rating  \
# 0   110000  Hurghada: Royal Seascope Submarine Cruise with...     4.5
# 1   110001  Sharm El-Sheikh: Seascope Submarine boat cruis...     4.5
# 2   110002  Hurghada: Semi-Submarine Boat Tour w/ Snorkeli...     4.2
# 3   110003  Hurghada: Sindbad Submarines Red Sea Underwate...     5.0
# 4   110004  Hurghada: Panoramic Semi-Submarine Cruise with...     4.5
# 6   110005  Marsa Alam: Royal Seascope Submarine Cruise wi...     4.3
# 7   110006  Hurghada: Paradise Island w/ Snorkeling & Opt ...     4.7
# 9   110007  Sharm El-Sheikh: Royal Seascope Submarine Crui...     3.9
# 10  110008  Hurghada: Empire Submarine Boat Trip with Snor...     3.4
# 11  110009  From El Gouna: Royal Seascope Submarine with S...     4.0
# 12  110010  Conquest 2 Hour Semi Submarine with snorkeling...     4.4
# 13  110011  Cairo: Ain Sokhna Semi-Submarine with optional...     5.0
# 14  110012  Sharm El-Sheikh: Ras Mohammed & White Island C...     3.7
# 15  110013        Dahab: Royal seascope Semi-Submarine Cruise     5.0
# 16  110014  Hurghada: Scenic Submarine Tour with Snorkelin...     3.7
#
#                                        Price  \
# 0     From\nE£1,264\nFrom\nE£884\nper person
# 1   From\nE£2,370\nFrom\nE£1,919\nper person
# 2       From\nE£421\nFrom\nE£316\nper person
# 3   From\nE£3,944\nFrom\nE£3,550\nper person
# 4     From\nE£1,843\nFrom\nE£921\nper person
# 6   From\nE£2,633\nFrom\nE£2,422\nper person
# 7     From\nE£1,843\nFrom\nE£921\nper person
# 9   From\nE£2,896\nFrom\nE£2,317\nper person
# 10    From\nE£1,086\nFrom\nE£814\nper person
# 11    From\nE£1,053\nFrom\nE£895\nper person
# 12      From\nE£421\nFrom\nE£316\nper person
# 13  From\nE£1,896\nFrom\nE£1,516\nper person
# 14    From\nE£1,315\nFrom\nE£657\nper person
# 15  From\nE£1,843\nFrom\nE£1,751\nper person
# 16    From\nE£1,086\nFrom\nE£923\nper person
#
#                                                  Link             City
# 0   https://www.getyourguide.com/hurghada-l403/hur...         Hurghada
# 1   https://www.getyourguide.com/sharm-el-sheikh-l...  Sharm El Sheikh
# 2   https://www.getyourguide.com/hurghada-l403/hur...         Hurghada
# 3   https://www.getyourguide.com/hurghada-l403/hur...         Hurghada
# 4   https://www.getyourguide.com/hurghada-l403/pan...         Hurghada
# 6   https://www.getyourguide.com/marsa-alam-l422/r...       Marsa Alam
# 7   https://www.getyourguide.com/hurghada-l403/hur...         Hurghada
# 9   https://www.getyourguide.com/sharm-el-sheikh-l...  Sharm El Sheikh
# 10  https://www.getyourguide.com/hurghada-l403/hur...         Hurghada
# 11  https://www.getyourguide.com/el-gouna-l1051/fr...         El Gouna
# 12  https://www.getyourguide.com/hurghada-l403/par...         Hurghada
# 13  https://www.getyourguide.com/cairo-l92/cairo-a...            Cairo
# 14  https://www.getyourguide.com/sharm-el-sheikh-l...  Sharm El Sheikh
# 15  https://www.getyourguide.com/dahab-l884/dahab-...            Dahab
# 16  https://www.getyourguide.com/hurghada-l403/hur...         Hurghada

# %% [markdown]
# ## Swimming With Dolphins Tours Dataset Handling

# %%
swimming_and_dolphins.head()
# Out:
#                                                Title  Rating  \
# 0  Hurghada or Makadi: Discover the Magic of Dolp...     4.9
# 1  Hurghada: Dolphin World Show with Walruses and...     4.3
# 2  Giza: Sakkara, Memphis & Dahshur (Pyramid & Fe...     4.8
# 3  Hurghada: Speedboat Dolphin Watching & Snorkel...     4.6
# 4  Hurghada: Dolphin Watching & Snorkeling Advent...     4.6
#
#                                       Price  \
# 0  From\nE£1,715\nFrom\nE£1,320\nper person
# 1                 From\nE£1,143\nper person
# 2    From\nE£1,364\nFrom\nE£682\nper person
# 3  From\nE£2,001\nFrom\nE£1,901\nper person
# 4    From\nE£1,315\nFrom\nE£986\nper person
#
#                                                 Link
# 0  https://www.getyourguide.com/hurghada-l403/hur...
# 1  https://www.getyourguide.com/hurghada-l403/hur...
# 2  https://www.getyourguide.com/cairo-l92/giza-sa...
# 3  https://www.getyourguide.com/giftun-island-l45...
# 4  https://www.getyourguide.com/hurghada-l403/hur...

# %%
swimming_and_dolphins['City'] = swimming_and_dolphins['Title'].apply(lambda x: extract_city_name(x, city_names))

# %%
swimming_and_dolphins = swimming_and_dolphins.dropna(subset=['City'])

# %%
swimming_and_dolphins = add_sequential_id (swimming_and_dolphins, 120000)

# %%
swimming_and_dolphins.head()
# Out:
#        id                                              Title  Rating  \
# 0  120000  Hurghada or Makadi: Discover the Magic of Dolp...     4.9
# 1  120001  Hurghada: Dolphin World Show with Walruses and...     4.3
# 2  120002  Giza: Sakkara, Memphis & Dahshur (Pyramid & Fe...     4.8
# 3  120003  Hurghada: Speedboat Dolphin Watching & Snorkel...     4.6
# 4  120004  Hurghada: Dolphin Watching & Snorkeling Advent...     4.6
#
#                                       Price  \
# 0  From\nE£1,715\nFrom\nE£1,320\nper person
# 1                 From\nE£1,143\nper person
# 2    From\nE£1,364\nFrom\nE£682\nper person
# 3  From\nE£2,001\nFrom\nE£1,901\nper person
# 4    From\nE£1,315\nFrom\nE£986\nper person
#
#                                                 Link      City
# 0  https://www.getyourguide.com/hurghada-l403/hur...  Hurghada
# 1  https://www.getyourguide.com/hurghada-l403/hur...  Hurghada
# 2  https://www.getyourguide.com/cairo-l92/giza-sa...      Giza
# 3  https://www.getyourguide.com/giftun-island-l45...  Hurghada
# 4  https://www.getyourguide.com/hurghada-l403/hur...  Hurghada

# %% [markdown]
# ## Inserting Activities Types

# %%
safari_data = insert_tourism_type (safari_data, 'Safari')
ballon_tours_data = insert_tourism_type (ballon_tours_data, 'Ballon Tours')
camel_tour = insert_tourism_type (camel_tour, 'Camel Tours')
diving_data = insert_tourism_type (diving_data, 'Diving')
submarine_tour = insert_tourism_type (submarine_tour, 'Submarine Tours')
swimming_and_dolphins = insert_tourism_type (swimming_and_dolphins, 'Swimming With Dolphins')

# %% [markdown]
# ## Merging Datasets After Processing

# %%
activities_df = pd.concat([safari_data, ballon_tours_data, camel_tour, diving_data, submarine_tour, swimming_and_dolphins], ignore_index=True)

# %%
activities_df
# Out:
#          id                                              Title  Rating  \
# 0      7000  Sharm El-Sheikh: Ultimate ATV Quad, Stargazing...     4.8
# 1      7001  Hurghada: Desert Quad Bike Camel Ride with Opt...     4.5
# 2      7002  Giza Sunrise Pyramid Guided Tour With Camel Ri...     4.8
# 3      7003  Hurghada: VIP Quad, Sea, Camel, Safari, Starga...     4.3
# 4      7004  Hurghada: Sunset Quad Bike, Camel w/ Opt Starg...     4.4
# ..      ...                                                ...     ...
# 360  120024  Cairo: 2-Day Pyramid, Museum, Bazaar Private Tour     4.5
# 361  120025  Cairo: Private Pharaonic Village Tour With Tan...     4.5
# 362  120026  Cairo: VIP Pyramids Sound & Light Show With Pr...     3.4
# 363  120027  Hurghada: 4 Days Tour Horse, Camel, Spa, ATV, ...     4.3
# 364  120028  From Cairo: Guided 4 Day Cairo & Red Sea Tour ...     4.5
#
#                                          Price  \
# 0     From\nE£2,001\nFrom\nE£1,000\nper person
# 1         From\nE£886\nFrom\nE£443\nper person
# 2     From\nE£2,046\nFrom\nE£1,023\nper person
# 3         From\nE£545\nFrom\nE£327\nper person
# 4         From\nE£852\nFrom\nE£511\nper person
# ..                                         ...
# 360   From\nE£4,092\nFrom\nE£2,046\nper person
# 361   From\nE£2,387\nFrom\nE£1,551\nper person
# 362   From\nE£3,069\nFrom\nE£1,995\nper person
# 363  From\nE£12,278\nFrom\nE£9,208\nper person
# 364                 From\nE£61,622\nper person
#
#                                                   Link             City  \
# 0    https://www.getyourguide.com/sharm-el-sheikh-l...  Sharm El Sheikh
# 1    https://www.getyourguide.com/hurghada-l403/hur...         Hurghada
# 2    https://www.getyourguide.com/cairo-l92/giza-su...             Giza
# 3    https://www.getyourguide.com/hurghada-l403/hur...         Hurghada
# 4    https://www.getyourguide.com/hurghada-l403/sun...         Hurghada
# ..                                                 ...              ...
# 360  https://www.getyourguide.com/cairo-l92/cairo-2...            Cairo
# 361  https://www.getyourguide.com/cairo-l92/cairo-p...            Cairo
# 362  https://www.getyourguide.com/cairo-l92/cairo-v...            Cairo
# 363  https://www.getyourguide.com/makadi-bay-l4675/...         Hurghada
# 364  https://www.getyourguide.com/cairo-l92/4-day-c...            Cairo
#
#               Activity Type
# 0                    Safari
# 1                    Safari
# 2                    Safari
# 3                    Safari
# 4                    Safari
# ..                      ...
# 360  Swimming With Dolphins
# 361  Swimming With Dolphins
# 362  Swimming With Dolphins
# 363  Swimming With Dolphins
# 364  Swimming With Dolphins
#
# [365 rows x 7 columns]

# %% [markdown]
# ## Uploading data To csv format

# %%
activities_df.to_csv("activities_data_after_proceesing.csv", index=False)

# %%
activities_df.columns
# Out:
# Index(['id', 'Title', 'Rating', 'Price', 'Link', 'City', 'Activity Type'], dtype='object')
